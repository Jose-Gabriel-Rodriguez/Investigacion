# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Gabriel-Rodriguez/Investigacion/blob/main/residencias/AnalisisDeResidencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)

# %% [markdown]
# # **Análisis de residencias profesionales en carreras afines a tecnologías de información en el ITD**
#
# **Rodriguez-Rivas José Gabriel**
# Tecnológico Nacional de México / Instituto Tecnológico de Durango
# **gabriel.rodriguez@itdurango.edu.mx**
#
# De acuerdo al manual de lineamientos académico-administrativos del Tecnológico Nacional de México, define la residencia profesional como una estrategia educativa con carácter curricular, que permite al estudiante emprender un proyecto de tipo teórico-práctico, analítico, reflexivo, crítico y profesional; cuyo propósito es el de resolver un problema para fortalecer y aplicar sus competencias profesionales (TecNM, 2015). Las prácticas pueden realizarse de manera individual, grupal o interdisciplinario, dependiendo de las condiciones y alcance del proyecto de la empresa o institución. La residencia tiene un valor curricular de 10 créditos y deben de cumplir 500 horas en un tiempo mínimo de cuatro meses a un máximo de seis meses.
#
# **Investigación disponible en:**
#
# https://sites.google.com/utd.edu.mx/praxis-educativa/publicaciones/per-22/v22-d1

# %% [markdown]
# ## **Metodología**:
# El presente estudio se desarrolló bajo un enfoque cuantitativo, que tal como lo señala Briones (2002) se utiliza información cuantificable para describir o tratar de explicar los fenómenos que se estudian. El diseño de la investigación es no experimental y de tipo transversal que de acuerdo con Hernández, Fernández, y Baptista (2010) se utilizan para describir y analizar variables en un momento dado, y de tipo descriptivo para establecer la forma de distribución de una o más variables en el ámbito del colectivo como lo señala Briones (2002).
# La técnica de recolección de datos consistió en el análisis de documentos oficiales y como instrumento, se utilizó una guía de observación estructurada con preguntas de tipo nominal con opciones múltiples que se llenó a partir de la información observada en el formato ITD-AC-PO-3-1 Rev.1 y del anteproyecto de residencia. Se realizó un censo con todos los proyectos registrados durante el periodo enero-junio 2018, agosto-diciembre 2018, enero-junio 2019 y agosto-diciembre 2019.
#
# ## **Conclusiones**
#
# Las principales conclusiones que se han encontrado a partir del análisis de las residencias se encontró que:
#
# * El 54% de las residencias se realizan en el sector privado, mientras que el 46% en el sector público, de los cuales el ITD apoyó a 43 alumnos y aunque esto ayude al ITD a satisfacer algunas necesidades resultaría conveniente buscar más la vinculación con otras empresas o instituciones.
#
# * Un bajo porcentaje (11%) de alumnos realizan sus residencias fuera de la ciudad, por lo que sería de suma importancia realizar los acuerdos necesarios con empresas foráneas a través de la vinculación para que más alumnos tuvieran la oportunidad de realizarla fuera de su estado.
#
# * Un 66% de las residencias se relacionan con el desarrollo de aplicaciones Web, móviles y sistemas de escritorio por lo que es importante reforzar las asignaturas relacionadas con programación, bases de datos, tratamiento y seguridad de la información.
#
# * Seria relevante realizar un estudio en las empresas e instituciones donde se realizan las residencias para conocer la opinión que tienen de los estudiantes acerca de sus habilidades y competencias para fortalecer las asignaturas que hagan falta.

# %% [markdown]
# ## **Librerias utilizadas y dataframe con los datos de residencias**

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# Librerias para nube e palabras
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import warnings
warnings.filterwarnings('ignore')

## Al dataframe se le agrego una columna llamada total para ahi desplegar
## los resultados de la funcion count en la agregación de datos

data = pd.read_csv("FormularioResidencias.csv", encoding="UTF-8")

# %%
# Obtener Cantidad de registros (observaciones) y variables
print(data.shape)
# Out:
# (237, 20)

# %%
# cantdad de registros u observaciones
len(data.index)
# Out:
# 237

# %%
# Mostrar los 2 primeros registros del dataframe para verificar la estructura e información
data.head(2)
# Out:
#                   NombreResidente     Genero  \
# 0  Karen Gisela Valdez Betancourt   Femenino
# 1        Edgar Iván Saucedo Rojas  Masculino
#
#                                   Carrera PeriodoResidencia  \
# 0  Ingenieria en Sistemas Computacionales  Enero-Junio 2018
# 1  Ingenieria en Sistemas Computacionales  Enero-Junio 2018
#
#                           Revisor  \
# 0  Deysi Berenice Castañeda Parra
# 1        Rafael Martínez Saavedra
#
#                                       NombreProyecto  \
# 0  Sistema Administrativo para el Registro y cont...
# 1  Desarrollo de Sistema para Control Financiero ...
#
#                  EmpresaInstitucion  \
# 0  D´tristan uniformes industriales
# 1                    Alta Seguridad
#
#                                             Objetivo   Sector  \
# 0  Crear un sistema que sea de ayuda y apoyo para...  Privado
# 1  Desarrollar un sistema capaz de almacenar info...  Privado
#
#                              OrigenProyecto              AlcanceProyecto  \
# 0  Iniciativa propia (propuesta del alumno)  Desarrollo nuevo desde cero
# 1  Iniciativa propia (propuesta del alumno)  Desarrollo nuevo desde cero
#
#   Region   Estado AreaAplicacionConocimiento  AlumnosAsignados  \
# 0  Local  Durango      Sistema de escritorio                 1
# 1  Local  Durango      Sistema de escritorio                 1
#
#   LenguajesProgramacion BasesDatos EntornoDesarrollo FrameworksDesarrollo  \
# 0                  Java      MySQL          Netbeans            No aplica
# 1                  Java      MySQL          Netbeans            No aplica
#
#    Total
# 0      1
# 1      1

# %%
# MOstrar los nombres de Carreras
data['Carrera'].unique()
# Out:
# array(['Ingenieria en Sistemas Computacionales',
#        'Ingenieria en Tecnologías de la Información y Comunicaciones',
#        'Ingenieria Informatica'], dtype=object)

# %%
## Seleccionar algunas columnas
data2 = data.iloc[ : , [0,4,5,6,7,12 ] ]

data2.head(2)
# Out:
#                   NombreResidente                         Revisor  \
# 0  Karen Gisela Valdez Betancourt  Deysi Berenice Castañeda Parra
# 1        Edgar Iván Saucedo Rojas        Rafael Martínez Saavedra
#
#                                       NombreProyecto  \
# 0  Sistema Administrativo para el Registro y cont...
# 1  Desarrollo de Sistema para Control Financiero ...
#
#                  EmpresaInstitucion  \
# 0  D´tristan uniformes industriales
# 1                    Alta Seguridad
#
#                                             Objetivo   Estado
# 0  Crear un sistema que sea de ayuda y apoyo para...  Durango
# 1  Desarrollar un sistema capaz de almacenar info...  Durango

# %% [markdown]
# ## **Número de alumnos por género por las tres carreras**

# %%
data['Genero'].value_counts()
# Out:
# Genero
# Masculino    165
# Femenino      72
# Name: count, dtype: int64

# %%
import seaborn as sns
# https://seaborn.pydata.org/generated/seaborn.countplot.html

plt.rcParams['figure.figsize'] = (7, 3)
#plt.style.use('_classic_test')
sns.countplot(data['Genero'], palette = 'dark')
plt.title('Número de Alumnos por Género', fontweight = 30)
plt.xlabel('Genero')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# ## **Numero de alumnos por carrera**
# Para obtener numero de alumnos por carrera se puede obtener de 4 formas ( o más):
# * Con la funcion  **value_counts()**
# * Con la funcion **group by** pero el resultado se refleja en todas las columnas
# * El segundo metodo lo podemos simplificar creando un dataframe con 2 columnas para que el resultado se muestre en la segunda columna
# * El tercero es crear un dataframe a partir del original con 2 columnas
# * El cuarto es simplemente indicar en que columna se mostrara el resultado omitiendo las demás columnas

# %%
# METODO 1
data['Carrera'].value_counts()
# Out:
# Carrera
# Ingenieria en Sistemas Computacionales                          152
# Ingenieria Informatica                                           50
# Ingenieria en Tecnologías de la Información y Comunicaciones     35
# Name: count, dtype: int64

# %%
# METODO 2,
# Agrupando y contando --- el resultado lo muestra en todas las columnas del dataframe
data.groupby('Carrera').count()
# Out:
#                                                     NombreResidente  Genero  \
# Carrera
# Ingenieria Informatica                                           50      50
# Ingenieria en Sistemas Computacionales                          152     152
# Ingenieria en Tecnologías de la Información y C...               35      35
#
#                                                     PeriodoResidencia  \
# Carrera
# Ingenieria Informatica                                             50
# Ingenieria en Sistemas Computacionales                            152
# Ingenieria en Tecnologías de la Información y C...                 35
#
#                                                     Revisor  NombreProyecto  \
# Carrera
# Ingenieria Informatica                                   50              50
# Ingenieria en Sistemas Computacionales                  152             152
# Ingenieria en Tecnologías de la Información y C...       35              35
#
#                                                     EmpresaInstitucion  \
# Carrera
# Ingenieria Informatica                                              50
# Ingenieria en Sistemas Computacionales                             152
# Ingenieria en Tecnologías de la Información y C...                  35
#
#                                                     Objetivo  Sector  \
# Carrera
# Ingenieria Informatica                                    48      50
# Ingenieria en Sistemas Computacionales                   146     152
# Ingenieria en Tecnologías de la Información y C...        33      35
#
#                                                     OrigenProyecto  \
# Carrera
# Ingenieria Informatica                                          50
# Ingenieria en Sistemas Computacionales                         152
# Ingenieria en Tecnologías de la Información y C...              35
#
#                                                     AlcanceProyecto  Region  \
# Carrera
# Ingenieria Informatica                                           50      50
# Ingenieria en Sistemas Computacionales                          152     152
# Ingenieria en Tecnologías de la Información y C...               35      35
#
#                                                     Estado  \
# Carrera
# Ingenieria Informatica                                  50
# Ingenieria en Sistemas Computacionales                 152
# Ingenieria en Tecnologías de la Información y C...      35
#
#                                                     AreaAplicacionConocimiento  \
# Carrera
# Ingenieria Informatica                                                      50
# Ingenieria en Sistemas Computacionales                                     152
# Ingenieria en Tecnologías de la Información y C...                          35
#
#                                                     AlumnosAsignados  \
# Carrera
# Ingenieria Informatica                                            50
# Ingenieria en Sistemas Computacionales                           152
# Ingenieria en Tecnologías de la Información y C...                35
#
#                                                     LenguajesProgramacion  \
# Carrera
# Ingenieria Informatica                                                 50
# Ingenieria en Sistemas Computacionales                                152
# Ingenieria en Tecnologías de la Información y C...                     35
#
#                                                     BasesDatos  \
# Carrera
# Ingenieria Informatica                                      50
# Ingenieria en Sistemas Computacionales                     152
# Ingenieria en Tecnologías de la Información y C...          35
#
#                                                     EntornoDesarrollo  \
# Carrera
# Ingenieria Informatica                                             50
# Ingenieria en Sistemas Computacionales                            152
# Ingenieria en Tecnologías de la Información y C...                 35
#
#                                                     FrameworksDesarrollo  \
# Carrera
# Ingenieria Informatica                                                50
# Ingenieria en Sistemas Computacionales                               152
# Ingenieria en Tecnologías de la Información y C...                    35
#
#                                                     Total
# Carrera
# Ingenieria Informatica                                 50
# Ingenieria en Sistemas Computacionales                152
# Ingenieria en Tecnologías de la Información y C...     35

# %%
# METODO 3    Creamos un segundo daaframe con las carreras y seleccionamos
# cualquier otra columna para mostrar ahi el resultado
# En este ejmplo se seleccionan todos los renglones y columnas 2 y 7
Carreras = data.iloc[ : , [ 2,5] ]
Carreras.head(3)
# Out:
#                                   Carrera  \
# 0  Ingenieria en Sistemas Computacionales
# 1  Ingenieria en Sistemas Computacionales
# 2  Ingenieria en Sistemas Computacionales
#
#                                       NombreProyecto
# 0  Sistema Administrativo para el Registro y cont...
# 1  Desarrollo de Sistema para Control Financiero ...
# 2  Aplicación Móvil para Registrar visitas a clie...

# %%
# Ahora si calculamos el numero de alumnos por carrera y lo mostramos
# en la columan del objetivo
Carreras.groupby('Carrera').count().sort_values(['NombreProyecto'], ascending=False)
# Out:
#                                                     NombreProyecto
# Carrera
# Ingenieria en Sistemas Computacionales                         152
# Ingenieria Informatica                                          50
# Ingenieria en Tecnologías de la Información y C...              35

# %%
# METODO 4 EL MAS DIRECTO
# Agrupamos por carrera y despues del count indicamos la columna donde queremos mostrar el resultado
data.groupby('Carrera').count()[['Total']].sort_values(['Total'], ascending=False)
# Out:
#                                                     Total
# Carrera
# Ingenieria en Sistemas Computacionales                152
# Ingenieria Informatica                                 50
# Ingenieria en Tecnologías de la Información y C...     35

# %% [markdown]
# ## **Graficar Alumnos por carrera**

# %%
# visualizar los diferentes grupos en el dataset

plt.rcParams['figure.figsize'] = (7, 3)
plt.style.use('ggplot')

# Barra vertical
# sns.countplot(data['Carrera'], palette = 'pink')

# Barra horizontal
sns.countplot(y=data['Carrera'], palette = 'pink')
plt.title('Alumnos por Carrera', fontweight = 30, fontsize = 20)
plt.xlabel('Alumnos', fontsize = 20)
plt.ylabel('Carrera', fontsize = 20)
plt.show()

# %% [markdown]
# ## **Número de alumnos por carrera y género**
# Al calcular numero de

# %%
##  Agrupamos por carrera y enseguida por genero y contabilizamos
data.groupby(['Carrera', 'Genero']).count()[['Total']]
# Out:
#                                                               Total
# Carrera                                            Genero
# Ingenieria Informatica                             Femenino      14
#                                                    Masculino     36
# Ingenieria en Sistemas Computacionales             Femenino      41
#                                                    Masculino    111
# Ingenieria en Tecnologías de la Información y C... Femenino      17
#                                                    Masculino     18

# %% [markdown]
# ### **Graficar número de alumnos por carrera y género**

# %%
# visualizar los diferentes grupos en el dataset

plt.rcParams['figure.figsize'] = (7, 3)
plt.style.use('ggplot')

# Barra vertical
# sns.countplot(data['Carrera'], palette = 'pink')

# Barra horizontal
sns.countplot(y=data['Carrera'], hue=data['Genero'], palette = 'pink')

plt.title('Alumnos por Carrera y género', fontweight = 30, fontsize = 20)
plt.xlabel('Alumnos', fontsize = 20)
plt.ylabel('Carrera', fontsize = 20)
plt.show()

# %% [markdown]
# ## **Residencias por periodo**

# %%
data.groupby(['PeriodoResidencia']).count()[['Total']]
# Out:
#                        Total
# PeriodoResidencia
# Agosto-Diciembre 2018     53
# Agosto-Diciembre 2019     60
# Enero-Junio 2018          59
# Enero-Junio 2019          65

# %% [markdown]
# ### **Residencias por periodo y Carrera**

# %%
data.groupby(['PeriodoResidencia','Carrera']).count()[['Total']]
# Out:
#                                                                           Total
# PeriodoResidencia     Carrera
# Agosto-Diciembre 2018 Ingenieria Informatica                                 13
#                       Ingenieria en Sistemas Computacionales                 29
#                       Ingenieria en Tecnologías de la Información y C...     11
# Agosto-Diciembre 2019 Ingenieria Informatica                                  7
#                       Ingenieria en Sistemas Computacionales                 45
#                       Ingenieria en Tecnologías de la Información y C...      8
# Enero-Junio 2018      Ingenieria Informatica                                 15
#                       Ingenieria en Sistemas Computacionales                 34
#                       Ingenieria en Tecnologías de la Información y C...     10
# Enero-Junio 2019      Ingenieria Informatica                                 15
#                       Ingenieria en Sistemas Computacionales                 44
#                       Ingenieria en Tecnologías de la Información y C...      6

# %% [markdown]
# ## **Gráficas de comparasión**

# %% [markdown]
# ### **Crear dataframe con numero de alumnos por carrera y por periodo**

# %%
##    sin usar UNSTACK

test5 = data.groupby(['PeriodoResidencia', 'Carrera'])['PeriodoResidencia'].count()
test5
# Out:
# PeriodoResidencia      Carrera
# Agosto-Diciembre 2018  Ingenieria Informatica                                          13
#                        Ingenieria en Sistemas Computacionales                          29
#                        Ingenieria en Tecnologías de la Información y Comunicaciones    11
# Agosto-Diciembre 2019  Ingenieria Informatica                                           7
#                        Ingenieria en Sistemas Computacionales                          45
#                        Ingenieria en Tecnologías de la Información y Comunicaciones     8
# Enero-Junio 2018       Ingenieria Informatica                                          15
#                        Ingenieria en Sistemas Computacionales                          34
#                        Ingenieria en Tecnologías de la Información y Comunicaciones    10
# Enero-Junio 2019       Ingenieria Informatica                                          15
#                        Ingenieria en Sistemas Computacionales                          44
#                        Ingenieria en Tecnologías de la Información y Comunicaciones     6
# Name: PeriodoResidencia, dtype: int64

# %%
##   USANDO UNSTACK
test5 = data.groupby(['PeriodoResidencia', 'Carrera'])['PeriodoResidencia'].count().unstack('PeriodoResidencia')
test5
# Out:
# PeriodoResidencia                                   Agosto-Diciembre 2018  \
# Carrera
# Ingenieria Informatica                                                 13
# Ingenieria en Sistemas Computacionales                                 29
# Ingenieria en Tecnologías de la Información y C...                     11
#
# PeriodoResidencia                                   Agosto-Diciembre 2019  \
# Carrera
# Ingenieria Informatica                                                  7
# Ingenieria en Sistemas Computacionales                                 45
# Ingenieria en Tecnologías de la Información y C...                      8
#
# PeriodoResidencia                                   Enero-Junio 2018  \
# Carrera
# Ingenieria Informatica                                            15
# Ingenieria en Sistemas Computacionales                            34
# Ingenieria en Tecnologías de la Información y C...                10
#
# PeriodoResidencia                                   Enero-Junio 2019
# Carrera
# Ingenieria Informatica                                            15
# Ingenieria en Sistemas Computacionales                            44
# Ingenieria en Tecnologías de la Información y C...                 6

# %%
plt.rcParams['figure.figsize'] = (12, 4)
plt.style.use('ggplot')
test5.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Carrera'>

# %%
##   USANDO UNSTACK
test5 = data.groupby(['Carrera', 'PeriodoResidencia'])['Carrera'].count().unstack('Carrera')
test5
# Out:
# Carrera                Ingenieria Informatica  \
# PeriodoResidencia
# Agosto-Diciembre 2018                      13
# Agosto-Diciembre 2019                       7
# Enero-Junio 2018                           15
# Enero-Junio 2019                           15
#
# Carrera                Ingenieria en Sistemas Computacionales  \
# PeriodoResidencia
# Agosto-Diciembre 2018                                      29
# Agosto-Diciembre 2019                                      45
# Enero-Junio 2018                                           34
# Enero-Junio 2019                                           44
#
# Carrera                Ingenieria en Tecnologías de la Información y Comunicaciones
# PeriodoResidencia
# Agosto-Diciembre 2018                                                 11
# Agosto-Diciembre 2019                                                  8
# Enero-Junio 2018                                                      10
# Enero-Junio 2019                                                       6

# %%
plt.figure(figsize=(7, 4))
test5.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='PeriodoResidencia'>

# %% [markdown]
# ## **Residencias por periodo, carrera y género**

# %%
data.groupby(['PeriodoResidencia','Carrera', 'Genero']).count()[['Total']]
# Out:
#                                                                                     Total
# PeriodoResidencia     Carrera                                            Genero
# Agosto-Diciembre 2018 Ingenieria Informatica                             Femenino       2
#                                                                          Masculino     11
#                       Ingenieria en Sistemas Computacionales             Femenino       9
#                                                                          Masculino     20
#                       Ingenieria en Tecnologías de la Información y C... Femenino       4
#                                                                          Masculino      7
# Agosto-Diciembre 2019 Ingenieria Informatica                             Femenino       1
#                                                                          Masculino      6
#                       Ingenieria en Sistemas Computacionales             Femenino      12
#                                                                          Masculino     33
#                       Ingenieria en Tecnologías de la Información y C... Femenino       2
#                                                                          Masculino      6
# Enero-Junio 2018      Ingenieria Informatica                             Femenino       4
#                                                                          Masculino     11
#                       Ingenieria en Sistemas Computacionales             Femenino      11
#                                                                          Masculino     23
#                       Ingenieria en Tecnologías de la Información y C... Femenino       7
#                                                                          Masculino      3
# Enero-Junio 2019      Ingenieria Informatica                             Femenino       7
#                                                                          Masculino      8
#                       Ingenieria en Sistemas Computacionales             Femenino       9
#                                                                          Masculino     35
#                       Ingenieria en Tecnologías de la Información y C... Femenino       4
#                                                                          Masculino      2

# %% [markdown]
# ## **Residencias por sector**

# %%
# Obtener numero de residencias por Total
data.groupby('Sector').count()[['Total']]

# 127 / 237 = 54%
# 110 / 237 = 46%
# Out:
#          Total
# Sector
# Privado    127
# Publico    110

# %%
# visualizing the differnt parental education levels

plt.rcParams['figure.figsize'] = (8, 4)
plt.style.use('fivethirtyeight')

sns.countplot(data['Sector'], palette = 'Blues')
plt.title('Residencias por sector', fontweight = 30, fontsize = 20)
plt.xlabel('Sector')
plt.ylabel('Cantidad')
plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
residenciasporSector  = data.groupby(['Sector']).count()[['Total']].sort_values(['Total'], ascending=False)

labels = residenciasporSector.index
values = residenciasporSector['Total'].values
explode = (0, 0.1)

plt.rcParams['figure.figsize'] = (8, 4)
fig1, ax1 = plt.subplots()
ax1.pie(values,  labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=45)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## **Residencias por Región**

# %%
data.groupby(['Region']).count()[['Total']].sort_values(['Total'], ascending=False)
# Out:
#          Total
# Region
# Local      210
# Foraneo     27

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
residenciasporregion  = data.groupby(['Region']).count()[['Total']].sort_values(['Total'], ascending=False)

labels = residenciasporregion.index
values = residenciasporregion['Total'].values
explode = (0, 0.1)

fig1, ax1 = plt.subplots()
ax1.pie(values, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=45)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## **Residencias por Estado**

# %%
# Ordenando el resultado

data.groupby('Estado').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                        Total
# Estado
# Durango                  211
# Nuevo León, Monterrey      5
# Coahuila, Torreón          5
# Ciudad de México           3
# Puebla                     2
# Queretaro                  2
# Saltillo, Coahuila         2
# Jalisco, Guadalajara       2
# Aguascalientes             1
# Chihuahua                  1
# Chihuahua, Cd Juarez       1
# Nuevo León                 1
# Jalisco, Tlaquepaque       1

# %%
data['Estado'].value_counts()
# Out:
# Estado
# Durango                  211
# Coahuila, Torreón          5
# Nuevo León, Monterrey      5
# Ciudad de México           3
# Jalisco, Guadalajara       2
# Queretaro                  2
# Saltillo, Coahuila         2
# Puebla                     2
# Jalisco, Tlaquepaque       1
# Nuevo León                 1
# Chihuahua, Cd Juarez       1
# Aguascalientes             1
# Chihuahua                  1
# Name: count, dtype: int64

# %% [markdown]
# ### **Graficando residencias por estado**

# %%
plt.rcParams['figure.figsize'] = (8, 4)
plt.style.use('tableau-colorblind10')

sns.countplot(y=data['Estado'], palette = 'prism')
plt.title('Residencias por Ciudad, Estado', fontweight = 30, fontsize = 20)
plt.xlabel('Cantidad')
plt.ylabel('Ciudad')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## **Residencias por Área de conocimiento**

# %% [markdown]
#  ### Tecnologia web se considero 105 + 4 + 2 + 2   =>     113
# * 4 de Tecnologia Web, Moviles
# * 2 de Tecnologia Web, bases de datos
# * 2 Tecnologia Web, Moviles, Sistema de escritorio, Arduinos
# * 2 Tecnologia Web, Redes
# * 2 Tecnologia Web, Moviles, Usabilidad
#
# ### Para sistemas de escritorio  27 + 2    =>  29
# * 2 Tecnologia Web, Moviles, Sistema de escritorio
#
# ### Para moviles   24 + 2 + 2   =>   28
# * 2 Tecnologia Web, Moviles, Sistema de escritorio, Arduinos
# * 2 Tecnologia Web, Moviles, Usabilidad
#
# ###  Para redes   23 + 2   =>     25
# * 2 Tecnologia Web, Redes

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
data.groupby('AreaAplicacionConocimiento').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                                                     Total
# AreaAplicacionConocimiento
# Tecnologia Web                                        105
# Sistema de escritorio                                  27
# Moviles                                                24
# Redes                                                  23
# Usabilidad / UX                                         7
# No aplica                                               6
# Documentacion de sistemas                               5
# Multimedia                                              5
# Tecnologia Web, Moviles                                 4
# Chatbot                                                 2
# Bases de datos                                          2
# Documentacion y pruebas                                 2
# Herramientas de monitoreo y análisis                    2
# Tecnologia Web, Moviles, Sistema de escritorio,...      2
# Tecnologia Web, Redes                                   2
# Tecnologia Web, Usabilidad / UX                         2
# Tecnologia Web, Bases de datos                          2
# Prototipo de sistema Web                                2
# Help Desk                                               1
# Instalacion de hardware/software, soporte, Conf...      1
# Control de acceso basado en roles                       1
# Desarrollo de scripts, agentes para monitorizac...      1
# Digitalización de expedientes                           1
# Análisis de Big Data                                    1
# Arduinos                                                1
# Domótica                                                1
# Documentación de red                                    1
# Documentacion y validacion                              1
# Investigación de procesos de trabajo                    1
# Scripts para generación de reportes                     1
# Software propietario a la medida                        1

# %%
#  Como la informacion de las AreaAplicacionConocimiento esta en una columna y vienen
#  multiples valores separados por coma, se tiene que crear un nuevo dataframe y hacer :
# "expandir" la columna en múltiples filas mediante unstack() y
# Despues borrra los espacios en blanco entre los valores de la lista
# (2) Aplicar un groupby() clásico para contar ahora sí las filas.


df_areas = pd.DataFrame(data["AreaAplicacionConocimiento"].str.split(',', expand=True).unstack(), columns=["AreaAplicacionConocimiento"])
df_areas = pd.DataFrame(df_areas['AreaAplicacionConocimiento'].str.strip())
df_areas['Total'] = 1

df_areas.head(10)
# Out:
#     AreaAplicacionConocimiento  Total
# 0 0      Sistema de escritorio      1
#   1      Sistema de escritorio      1
#   2                    Moviles      1
#   3      Sistema de escritorio      1
#   4             Tecnologia Web      1
#   5             Tecnologia Web      1
#   6                    Moviles      1
#   7                    Moviles      1
#   8                  No aplica      1
#   9      Sistema de escritorio      1

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
df_areas.groupby('AreaAplicacionConocimiento').count()[['Total']].sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                                        Total
# AreaAplicacionConocimiento
# Tecnologia Web                           117
# Moviles                                   30
# Sistema de escritorio                     29
# Redes                                     25
# Usabilidad / UX                            9
# No aplica                                  6
# Multimedia                                 5
# Documentacion de sistemas                  5
# Bases de datos                             4
# Arduinos                                   3
# Herramientas de monitoreo y análisis       2
# Documentacion y pruebas                    2
# Chatbot                                    2
# Prototipo de sistema Web                   2
# Documentación de red                       1
# Documentacion y validacion                 1
# Digitalización de expedientes              1
# Control de acceso basado en roles          1
# Desarrollo de scripts                      1
# Análisis de Big Data                       1
# Configuracion de tablets                   1
# Domótica                                   1
# Instalacion de hardware/software           1
# Investigación de procesos de trabajo       1
# Help Desk                                  1
# Software propietario a la medida           1
# Scripts para generación de reportes        1
# agentes para monitorización y alertas      1
# soporte                                    1

# %% [markdown]
# ### **Número de alumnos asignados por proyecto**

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
data.groupby('AlumnosAsignados').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                   Total
# AlumnosAsignados
# 1                   123
# 2                   100
# 3                    14

# %% [markdown]
# ### **Lenguajes de Programación mas utilizados**

# %% [markdown]
# ## Conteo manual para verificar coincidencias con la solucion planteada
# Para PHP  28 + 25 + 5 + 3 +3  +1 +1 +1 +1   =>     68
#
# Para Javascript   25  + 14 +3 +3+ 2+ 2  +1 +1 +1 +1 +1 +1 =>     55
#
# Para Java  36 + 5 + 4  +3 +1 +1 +1 +1 +1 +1  =>  54
#
# Para c#     12 + 4 + 2  + 2 + 1 + 1 +1 +1  =>   25
#
# Typescript  3 +3 +1  + 1 +1   =>  9
#
# Python   1 +1 + 1   =>  3
#
# Ruby  2
# swift, Objective-c, Ruby, visual basic c++   2veces, kotlyn

# %%
# los valores vienen en ocasiones separados por coma
# mas adelante se plantea la solucion
data.groupby('LenguajesProgramacion').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                                        Total
# LenguajesProgramacion
# No aplica                                 73
# Java                                      40
# PHP                                       28
# PHP, Javascript                           25
# C#                                        18
# Javascript                                14
# PHP, Java                                  5
# C#, Javascript                             4
# PHP, Java, Javascript                      4
# Javascript, Typescript                     4
# PHP, Typescript                            3
# Herramientas y tecnicas de usabilidad      2
# C# , Javascript,                           1
# Javascript, Typescript, C#                 1
# Javascript, Ruby                           1
# Java, C++, Javascript                      1
# Java, Python                               1
# Java, C#                                   1
# C++                                        1
# PHP, Java, Kotlin                          1
# PHP, C#                                    1
# PHP, Java, swift, Objective-c              1
# Python                                     1
# Python, C#                                 1
# Python, ECMA Script                        1
# Ruby                                       1
# Typescript                                 1
# Visual Basic                               1
# Visual basic para Aplicaciones             1

# %%
# otra forma de sacar la info
data['LenguajesProgramacion'].value_counts().head()
# Out:
# LenguajesProgramacion
# No aplica          73
# Java               40
# PHP                28
# PHP, Javascript    25
# C#                 18
# Name: count, dtype: int64

# %%
#  Como la informacion de los lenguajes esta en una columna y vienen multiples
# valores separados por coma, se tiene que crear un nuevo dataframe y hacer :
# "expandir" la columna en múltiples filas mediante unstack() y
# Despues borrra los espacios en blanco entre los valores de la lista
# (2) Aplicar un groupby() clásico para contar ahora sí las filas.


df_lenguajes = pd.DataFrame(data["LenguajesProgramacion"].str.split(',', expand=True).unstack(), columns=["LenguajesProgramacion"])
df_lenguajes = pd.DataFrame(df_lenguajes['LenguajesProgramacion'].str.strip())
df_lenguajes['Total'] = 1

df_lenguajes.head()
# Out:
#     LenguajesProgramacion  Total
# 0 0                  Java      1
#   1                  Java      1
#   2             No aplica      1
#   3                  Java      1
#   4             No aplica      1

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
df_lenguajes.groupby('LenguajesProgramacion').count()[['Total']].sort_values(['Total'],
                                            ascending=False)[['Total']]
# Out:
#                                        Total
# LenguajesProgramacion
# No aplica                                 73
# PHP                                       68
# Javascript                                55
# Java                                      54
# C#                                        27
# Typescript                                 9
# Python                                     4
# Herramientas y tecnicas de usabilidad      2
# C++                                        2
# Ruby                                       2
#                                            1
# Kotlin                                     1
# ECMA Script                                1
# Objective-c                                1
# Visual Basic                               1
# Visual basic para Aplicaciones             1
# swift                                      1

# %% [markdown]
# ### **Bases de Datos mas utilizados**

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
data.groupby('BasesDatos').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                  Total
# BasesDatos
# No aplica           99
# MySQL               79
# SQL Server          21
# Firebase            12
# Sybase               7
# PostgreSQL           4
# SQLite               4
# Oracle               4
# MongoDB, SQLite      3
# Informix             1
# DinamoDB             1
# MySQL, MongoDB       1
# MySQL, Oracle        1

# %%
#  Como la informacion de los BASES DE DATOS esta en una columna y vienen multiples
# valores separados por coma, se tiene que crear un nuevo dataframe y hacer :
# "expandir" la columna en múltiples filas mediante unstack() y
# Despues borrra los espacios en blanco entre los valores de la lista
# (2) Aplicar un groupby() clásico para contar ahora sí las filas.


df_bd = pd.DataFrame(data["BasesDatos"].str.split(',', expand=True).unstack(), columns=["BasesDatos"])
df_bd = pd.DataFrame(df_bd['BasesDatos'].str.strip())
df_bd['Total'] = 1

df_bd.head(10)
# Out:
#     BasesDatos  Total
# 0 0      MySQL      1
#   1      MySQL      1
#   2  No aplica      1
#   3      MySQL      1
#   4  No aplica      1
#   5  No aplica      1
#   6   Firebase      1
#   7   Firebase      1
#   8  No aplica      1
#   9      MySQL      1

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
df_bd.groupby('BasesDatos').count()[['Total']].sort_values(['Total'], ascending=False)[['Total']]
# Out:
#             Total
# BasesDatos
# No aplica      99
# MySQL          81
# SQL Server     21
# Firebase       12
# SQLite          7
# Sybase          7
# Oracle          5
# MongoDB         4
# PostgreSQL      4
# Informix        1
# DinamoDB        1

# %% [markdown]
# ### **Entornos de Programación mas utilizados   IDEs**

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
data.groupby('EntornoDesarrollo').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                                                 Total
# EntornoDesarrollo
# No Aplica                                          91
# Sublime                                            54
# Visual Studio                                      23
# Netbeans                                           19
# Android Studio                                     13
# Visual Code                                        10
# Atom                                                4
# Sublime, Netbeans, Visual Code                      4
# Dreamweaver                                         4
# Sublime, Netbeans                                   3
# Unity                                               3
# Xamarin, Visual Code                                2
# Eclipse                                             2
# Sublime, Netbeans, Android Studio, IDE Arduino      1
# Sublime, Netbeans, Eclipse, Android Studio          1
# Sublime, Netbeans, IDE Arduino                      1
# Sublime, Visual Code                                1
# WIX                                                 1

# %%
#  Como la informacion de los Entornos de programación esta en una columna y vienen multiples
# valores separados por coma, se tiene que crear un nuevo dataframe y hacer :
# "expandir" la columna en múltiples filas mediante unstack() y
# Despues borrra los espacios en blanco entre los valores de la lista
# (2) Aplicar un groupby() clásico para contar ahora sí las filas.


df_ides = pd.DataFrame(data["EntornoDesarrollo"].str.split(',', expand=True).unstack(), columns=["EntornoDesarrollo"])
df_ides = pd.DataFrame(df_ides['EntornoDesarrollo'].str.strip())
df_ides['Total'] = 1

df_ides.head(10)
# Out:
#     EntornoDesarrollo  Total
# 0 0          Netbeans      1
#   1          Netbeans      1
#   2         No Aplica      1
#   3          Netbeans      1
#   4         No Aplica      1
#   5         No Aplica      1
#   6    Android Studio      1
#   7    Android Studio      1
#   8         No Aplica      1
#   9          Netbeans      1

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
df_ides.groupby('EntornoDesarrollo').count()[['Total']].sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                    Total
# EntornoDesarrollo
# No Aplica             91
# Sublime               65
# Netbeans              29
# Visual Studio         23
# Visual Code           17
# Android Studio        15
# Atom                   4
# Dreamweaver            4
# Eclipse                3
# Unity                  3
# IDE Arduino            2
# Xamarin                2
# WIX                    1

# %% [markdown]
# ## **Frameworks de desarrollo  mas utilizados**

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
data.groupby('FrameworksDesarrollo').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                                                   Total
# FrameworksDesarrollo
# No aplica                                           147
# Ionic                                                 7
# Angular JS                                            6
# Wordpress                                             6
# Bootstrap                                             4
# Angular JS, Ionic                                     4
# Angular JS, Node JS                                   3
# Angular JS, JQuery, Bootstrap                         3
# Elastick Stack 6.3: Beats, Elasticsearch, Kibana      3
# Unity                                                 3
# Bootstrap, JQuery                                     3
# Ionic, Cordova                                        3
# JQuery                                                2
# AutoPano giga, PanoTour                               2
# ASP.NET                                               2
# React, Node JS,                                       2
# Ionic, Unity                                          2
# Node JS                                               2
# Spring, JHipster, JDL, HQL                            2
# Xamarin                                               2
# No aplica, DialogFlow                                 2
# Angular JS, Spring, Maven, Hibernate                  1
# Angular JS, DialogFlow, Materialize CSS               1
# Angular JS, Maven, Hibernate, Node JS                 1
# Angular JS, ASP.NET, Node JS, Jenkins                 1
# Angular JS, Spring, Node JS, Hibernate, Maven         1
# Angular JS, Node JS, BoilerPlate                      1
# Angular JS, Node JS, Boilerplate                      1
# Angular JS, Node JS,                                  1
# ASP.NET, Xamarin,                                     1
# Ionic, Cordova, Node JS                               1
# Bootstrap,                                            1
# Kimai, TestLink, MantisBT                             1
# Laravel                                               1
# JQuery, Bootstrap                                     1
# Kimai, TestLink                                       1
# ERP Odoo                                              1
# CakePHP                                               1
# No aplica, Webflow, Sketch                            1
# Node JS,                                              1
# SharePoint                                            1
# Ruby on rails, VueJS                                  1
# Ruby on rails                                         1
# React, Polymer                                        1
# Spring-boot, Hibernate                                1
# Spring                                                1
# Sktech, Invision                                      1
# Wix Code                                              1

# %%
#  Como la informacion de los Frameworks esta en una columna y vienen multiples
# valores separados por coma, se tiene que crear un nuevo dataframe y hacer :
# "expandir" la columna en múltiples filas mediante unstack() y
# Despues borrra los espacios en blanco entre los valores de la lista
# (2) Aplicar un groupby() clásico para contar ahora sí las filas.


df_fd = pd.DataFrame(data["FrameworksDesarrollo"].str.split(',', expand=True).unstack(), columns=["FrameworksDesarrollo"])
df_fd = pd.DataFrame(df_fd['FrameworksDesarrollo'].str.strip())
df_fd['Total'] = 1
# mostrar los primeros 10
df_fd.head(10)
# Out:
#     FrameworksDesarrollo  Total
# 0 0            No aplica      1
#   1            No aplica      1
#   2                Ionic      1
#   3            No aplica      1
#   4            Wordpress      1
#   5            Wordpress      1
#   6                Ionic      1
#   7                Ionic      1
#   8            No aplica      1
#   9            No aplica      1

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
df_fd.groupby('FrameworksDesarrollo').count()[['Total']].sort_values(['Total'],
                                     ascending=False)[['Total']]
# Out:
#                            Total
# FrameworksDesarrollo
# No aplica                    150
# Angular JS                    24
# Ionic                         17
# Node JS                       15
# Bootstrap                     12
# JQuery                         9
#                                6
# Wordpress                      6
# Spring                         5
# Unity                          5
# Hibernate                      4
# Cordova                        4
# ASP.NET                        4
# React                          3
# Kibana                         3
# Maven                          3
# Xamarin                        3
# DialogFlow                     3
# Elastick Stack 6.3: Beats      3
# Elasticsearch                  3
# AutoPano giga                  2
# Ruby on rails                  2
# TestLink                       2
# PanoTour                       2
# HQL                            2
# Kimai                          2
# JHipster                       2
# JDL                            2
# BoilerPlate                    1
# ERP Odoo                       1
# CakePHP                        1
# Boilerplate                    1
# Materialize CSS                1
# Invision                       1
# MantisBT                       1
# Laravel                        1
# Jenkins                        1
# Sktech                         1
# Sketch                         1
# SharePoint                     1
# Polymer                        1
# VueJS                          1
# Spring-boot                    1
# Wix Code                       1
# Webflow                        1

# %% [markdown]
# ## **Empresa / Institucion mas frecuentes**

# %%
# Agrupamos la informacion, contamos y mostramos de mayor a menor
data.groupby('EmpresaInstitucion').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                                                     Total
# EmpresaInstitucion
# ITD Instituto Tecnológico de Durango                   43
# EISEI                                                   8
# Ventus Technology                                       8
# SEED Secretaria de Educación del Estado de Durango      6
# TELMEX Teléfonos de México SA de CV                     5
# ...                                                   ...
# VIRTUA MX                                               1
# Ventus technology                                       1
# Virtua MX                                               1
# Visión consultora y desarrollo empresarial  S.A...      1
# Yazaki                                                  1
#
# [124 rows x 1 columns]

# %%
data.groupby('NombreResidente').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                                     Total
# NombreResidente
# Aaron Isaac Calderón Castor             1
# Aarón Avila de la Hoya                  1
# Abraham Ricardo Rodriguez Sierra        1
# Adrian Steven Mendoza Huerta            1
# Alejandro Marrufo Quintana              1
# ...                                   ...
# Xiomara Arely Fernández Saldaña         1
# Yair Alberto Herrera Duarte             1
# Yesica Guadalupe Garcia Sánchez         1
# Yotzin Alexander Contreras Herrera      1
# Zurisadai Ruiz Sanchez                  1
#
# [237 rows x 1 columns]

# %%
data.groupby('NombreProyecto').count().sort_values(['Total'], ascending=False)[['Total']]
# Out:
#                                                     Total
# NombreProyecto
# Aplicación interactiva para promoción académica...      3
# Sistema de Geolocalización y Gestión de los Rec...      3
# Sistema de gestión para tramites entrantes del ...      3
# Rediseño Frontend del sitio Web de la unidad de...      3
# Aplicación Móvil para la administración y orien...      2
# ...                                                   ...
# Sitio Web y e-commerce María de México                  1
# Software punto de remisión y terminal refaccion...      1
# Virtuamx Internal Monitor System                        1
# Visibilidad 360 IT                                      1
# WTRACK: Seguidor de trabajo y productividad             1
#
# [182 rows x 1 columns]

# %% [markdown]
# ## **Nube de palabras**
# * Definir una funcion para llamarla cada vez que se necesite
# * Definir palabras que se omiten
# + Se definen parametros como numero maximo de palabras, tamaño máximo de la fuente, contorno de la imagen a mostrar

# %%
# Obtener unicamente los objetivos para nube de palabras
objetivos = data.iloc[ : , 7 ]
objetivos.head()
# Out:
# 0    Crear un sistema que sea de ayuda y apoyo para...
# 1    Desarrollar un sistema capaz de almacenar info...
# 2    Desarrollar una aplicación móvil para la gesti...
# 3    Crear un Sistema para administrar todas las de...
# 4    Diseñar y desarrollar un portal de difusión e ...
# Name: Objetivo, dtype: object

# %%
# 1. stopwords permite eliminar palabras irrelevantes para el análisis
max_words=60
stopwords = set(STOPWORDS)
more_stopwords = {'y', 'de', 'para', 'un', 'las', 'en', 'con', 'el', 'la', 'una','que', 'del', 'los','se',
                  'cual','al','por','e','o','Durango','como','su','así' }
stopwords = stopwords.union(more_stopwords)

# Une todos los textos en un solo string
texto = " ".join(objetivos.astype(str))

# 3. Crear la nube de palabras
wordcloud = WordCloud(
    width=800,          # ancho de la imagen
    height=400,         # alto de la imagen
    stopwords = stopwords,
    max_words = max_words,# número máximo de palabras
    background_color="white",  # color de fondo
    colormap="viridis", # paleta de colores (puedes probar 'plasma', 'inferno', etc.)
    collocations=False  # evita repetir combinaciones de palabras
).generate(texto)

# 4. Mostrar la nube
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# Agregar título
plt.title("Nube de palabras - Palabras mas usadas en los objetivos de residencia profesional", fontsize=16, pad=20)
plt.show()
